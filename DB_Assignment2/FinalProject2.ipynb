# %% [markdown]
# # Final Project
# ## Topic : Tennis

# %% [markdown]
# ## Set up database and create tables

# %% [markdown]
# ### Part 1: Connect the database

# %%
# %reload_ext sql

# %%
try:
    import pymysql
    pymysql.install_as_MySQLdb()
except ImportError:
    pass

# %%
# %sql mysql://root:root@localhost:8889/DB_FinalProject
# Out:
# 'Connected: root@DB_FinalProject'

# %% [markdown]
# ### Part 2: Create tables

# %%
#Create 'court' table
# %sql CREATE TABLE IF NOT EXISTS court (court_id int,\
                                       court_conditions varchar(20),\
                                       court_surface varchar(20)\
                                      )
# Out:
# 0 rows affected.
# []

# %%
#Create 'coach' table
# %sql CREATE TABLE IF NOT EXISTS coach (coach_id int PRIMARY KEY,\
                                       coach_name varchar(50),\
                                       coaching_player_id varchar(10)\
)
# Out:
# 0 rows affected.
# []

# %%
#Create 'player' table
# %sql CREATE TABLE IF NOT EXISTS player (player_id varchar(10) PRIMARY KEY,\
                                        first_name varchar(30),\
                                        last_name varchar(30),\
                                        flag_code varchar(10),\
                                        birth_year int,\
                                        birth_month int,\
                                        birth_day int,\
                                        turned_pro int,\
                                        weight_kg int,\
                                        height_cm int,\
                                        handedness varchar(30),\
                                        backhand varchar(30),\
                                        fullname varchar(100)\
                                       )
# Out:
# 0 rows affected.
# []

# %%
#Create 'tournament' table
# %sql CREATE TABLE IF NOT EXISTS tournament (tourney_year_id varchar(20) PRIMARY KEY,\
                                            tourney_year int,\
                                            tourney_order int,\
                                            tourney_name varchar(30),\
                                            tourney_id int,\
                                            tourney_slug varchar(30),\
                                            tourney_location varchar(50),\
                                            tourney_dates varchar(20),\
                                            singles_winner_player_id varchar(10),\
                                            doubles_winner_1_player_id varchar(10),\
                                            doubles_winner_2_player_id varchar(10),\
                                            court_id int\
                                           )
# Out:
# 0 rows affected.
# []

# %%
#Alter the table attribute 
# %sql ALTER TABLE `tournament` CHANGE `tourney_name` `tourney_name` VARCHAR(60) CHARACTER SET utf8 \
COLLATE utf8_general_ci NULL DEFAULT NULL;
# Out:
# 0 rows affected.
# []

# %%
#Create 'match_info' table
# %sql CREATE TABLE IF NOT EXISTS match_info (match_id varchar(30) PRIMARY KEY,\
                                       tourney_year_id varchar(15),\
                                       tourney_round_name varchar(20),\
                                       round_order int,\
                                       match_order int,\
                                       winner_player_id varchar(10),\
                                       loser_player_id varchar(10),\
                                       winner_seed varchar(5),\
                                       loser_seed varchar(5),\
                                       match_score_tiebreaks varchar(30),\
                                       winner_sets_won int,\
                                       loser_sets_won int,\
                                       winner_games_won int,\
                                       loser_games_won int,\
                                       winner_tiebreaks_won int,\
                                       loser_tiebreaks_won int\
                                      )
# Out:
# 0 rows affected.
# []

# %%
#Create 'match_stats' table
# %sql CREATE TABLE IF NOT EXISTS match_stats (tourney_order int,\
                                             match_id varchar(30),\
                                             match_duration int,\
                                             winner_aces int,\
                                             winner_double_faults int,\
                                             winner_first_serves_in int,\
                                             winner_first_serves_total int,\
                                             winner_first_serve_points_won int,\
                                             winner_first_serve_points_total int,\
                                             winner_second_serve_points_won int,\
                                             winner_second_serve_points_total int,\
                                             winner_break_points_saved int,\
                                             winner_break_points_serve_total int,\
                                             winner_service_points_won int,\
                                             winner_service_points_total int,\
                                             winner_first_serve_return_won int,\
                                             winner_first_serve_return_total int,\
                                             winner_second_serve_return_won int,\
                                             winner_second_serve_return_total int,\
                                             winner_break_points_converted int,\
                                             winner_break_points_return_total int,\
                                             winner_service_games_played int,\
                                             winner_return_games_played int,\
                                             winner_return_points_won int,\
                                             winner_return_points_total int,\
                                             winner_total_points_won int,\
                                             winner_total_points_total int,\
                                             loser_aces int,\
                                             loser_double_faults int,\
                                             loser_first_serves_in int,\
                                             loser_first_serves_total int,\
                                             loser_first_serve_points_won int,\
                                             loser_first_serve_points_total int,\
                                             loser_second_serve_points_won int,\
                                             loser_second_serve_points_total int,\
                                             loser_break_points_saved int,\
                                             loser_break_points_serve_total int,\
                                             loser_service_points_won int,\
                                             loser_service_points_total int,\
                                             loser_first_serve_return_won int,\
                                             loser_first_serve_return_total int,\
                                             loser_second_serve_return_won int,\
                                             loser_second_serve_return_total int,\
                                             loser_break_points_converted int,\
                                             loser_break_points_return_total int,\
                                             loser_service_games_played int,\
                                             loser_return_games_played int,\
                                             loser_return_points_won int,\
                                             loser_return_points_total int,\
                                             loser_total_points_won int,\
                                             loser_total_points_total int\
                                            )
# Out:
# 0 rows affected.
# []

# %%
#Create 'ranking' table
# %sql CREATE TABLE IF NOT EXISTS ranking (ranking_id int PRIMARY KEY AUTO_INCREMENT,\
                                         week_title varchar(15),\
                                         week_year int,\
                                         week_month int,\
                                         week_day int,\
                                         rank_text varchar(10),\
                                         rank_number int,\
                                         move_positions int,\
                                         move_direction varchar(10),\
                                         player_age int,\
                                         ranking_points int,\
                                         tourneys_played int,\
                                         player_id varchar(10)\
                                        )
# Out:
# 0 rows affected.
# []

# %% [markdown]
# ### Part 3: Load the data into tables

# %% [markdown]
# #### 3.1 Import the data of table 'court'

# %%
# %sql LOAD DATA INFILE '/Users/shixinying/Desktop/ATPdataset/court.csv' \
INTO TABLE court CHARACTER SET utf8 \
FIELDS TERMINATED BY ',' \
ENCLOSED BY '"'\
IGNORE 1 ROWS
# Out:
# 199 rows affected.
# []

# %% [markdown]
# #### 3.2 Import the data of table 'coach'

# %%
# %sql LOAD DATA INFILE '/Users/shixinying/Desktop/ATPdataset/coachfullname.csv' \
INTO TABLE coach CHARACTER SET utf8 \
FIELDS TERMINATED BY ',' \
ENCLOSED BY '"'\
IGNORE 1 ROWS
# Out:
# 193 rows affected.
# []

# %% [markdown]
# #### 3.3 Import the data of table 'match_info'

# %%
# %sql LOAD DATA INFILE '/Users/shixinying/Desktop/ATPdataset/match_scores_2015-2017_UNINDEXED.csv' \
INTO TABLE match_info CHARACTER SET utf8 \
FIELDS TERMINATED BY ',' \
ENCLOSED BY '"'\
IGNORE 1 ROWS
# Out:
# 12219 rows affected.
# []

# %% [markdown]
# #### 3.4 Import the data of table 'tournament'

# %%
# %sql LOAD DATA INFILE '/Users/shixinying/Desktop/ATPdataset/tournaments2015-2017.csv' \
INTO TABLE tournament CHARACTER SET utf8 \
FIELDS TERMINATED BY ',' \
ENCLOSED BY '"'\
IGNORE 1 ROWS
# Out:
# 198 rows affected.
# []

# %% [markdown]
# #### 3.5 Import the data of table 'match_stats'

# %%
# %sql LOAD DATA INFILE '/Users/shixinying/Desktop/ATPdataset/match_stats_2015-2017_UNINDEXED.csv' \
INTO TABLE match_stats CHARACTER SET utf8 \
FIELDS TERMINATED BY ',' \
ENCLOSED BY '"'\
IGNORE 1 ROWS
# Out:
# 3811 rows affected.
# []

# %% [markdown]
# #### 3.6 Import the data of table 'player'

# %%
#Cause some columes' data is null and we think they will not influence the analyse, so we just keep them.
# However, when import the data to mysql, they will be filled with 0.
# %sql LOAD DATA INFILE '/Users/shixinying/Desktop/ATPdataset/newplayer.csv' \
INTO TABLE player CHARACTER SET utf8 \
FIELDS TERMINATED BY ',' \
ENCLOSED BY '"'\
IGNORE 1 ROWS
# Out:
# 2598 rows affected.
# /Users/shixinying/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:165: Warning: (1366, "Incorrect integer value: '' for column 'turned_pro' at row 37")
#   result = self._query(query)
# /Users/shixinying/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:165: Warning: (1366, "Incorrect integer value: '' for column 'turned_pro' at row 65")
#   result = self._query(query)
# /Users/shixinying/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:165: Warning: (1366, "Incorrect integer value: '' for column 'turned_pro' at row 79")
#   result = self._query(query)
# /Users/shixinying/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:165: Warning: (1366, "Incorrect integer value: '' for column 'weight_kg' at row 79")
#   result = self._query(query)
# /Users/shixinying/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:165: Warning: (1366, "Incorrect integer value: '' for column 'height_cm' at row 79")
#   result = self._query(query)
# ...

# %% [markdown]
# #### 3.7 Import the data of table 'ranking'

# %%
#Import the 2015 year's data
# %sql LOAD DATA INFILE '/Users/shixinying/Desktop/ATPdataset/rankings_2015.csv' \
INTO TABLE ranking CHARACTER SET utf8 \
FIELDS TERMINATED BY ',' \
ENCLOSED BY '"'\
IGNORE 1 ROWS\
(week_title,week_year,week_month,week_day,rank_text,rank_number,move_positions,move_direction,player_age,ranking_points,tourneys_played,player_id)
# Out:
# 65499 rows affected.
# /Users/shixinying/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:165: Warning: (1366, "Incorrect integer value: '' for column 'move_positions' at row 1")
#   result = self._query(query)
# /Users/shixinying/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:165: Warning: (1366, "Incorrect integer value: '' for column 'move_positions' at row 2")
#   result = self._query(query)
# /Users/shixinying/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:165: Warning: (1366, "Incorrect integer value: '' for column 'move_positions' at row 3")
#   result = self._query(query)
# /Users/shixinying/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:165: Warning: (1366, "Incorrect integer value: '' for column 'move_positions' at row 4")
#   result = self._query(query)
# /Users/shixinying/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:165: Warning: (1366, "Incorrect integer value: '' for column 'move_positions' at row 5")
# ...

# %%
#Import the 2016 year's data
# %sql LOAD DATA INFILE '/Users/shixinying/Desktop/ATPdataset/rankings_2016.csv' \
INTO TABLE ranking CHARACTER SET utf8 \
FIELDS TERMINATED BY ',' \
ENCLOSED BY '"'\
IGNORE 1 ROWS\
(week_title,week_year,week_month,week_day,rank_text,rank_number,move_positions,move_direction,player_age,ranking_points,tourneys_played,player_id)
# Out:
# 65499 rows affected.
# /Users/shixinying/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:165: Warning: (1366, "Incorrect integer value: '' for column 'move_positions' at row 1")
#   result = self._query(query)
# /Users/shixinying/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:165: Warning: (1366, "Incorrect integer value: '' for column 'move_positions' at row 2")
#   result = self._query(query)
# /Users/shixinying/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:165: Warning: (1366, "Incorrect integer value: '' for column 'move_positions' at row 3")
#   result = self._query(query)
# /Users/shixinying/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:165: Warning: (1366, "Incorrect integer value: '' for column 'move_positions' at row 4")
#   result = self._query(query)
# /Users/shixinying/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:165: Warning: (1366, "Incorrect integer value: '' for column 'move_positions' at row 5")
# ...

# %%
# Import the 2017 year's data
# %sql LOAD DATA INFILE '/Users/shixinying/Desktop/ATPdataset/rankings_2017.csv' \
INTO TABLE ranking CHARACTER SET utf8 \
FIELDS TERMINATED BY ',' \
ENCLOSED BY '"'\
IGNORE 1 ROWS\
(week_title,week_year,week_month,week_day,rank_text,rank_number,move_positions,move_direction,player_age,ranking_points,tourneys_played,player_id)
# Out:
# 65499 rows affected.
# /Users/shixinying/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:165: Warning: (1366, "Incorrect integer value: '' for column 'move_positions' at row 1")
#   result = self._query(query)
# /Users/shixinying/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:165: Warning: (1366, "Incorrect integer value: '' for column 'move_positions' at row 2")
#   result = self._query(query)
# /Users/shixinying/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:165: Warning: (1366, "Incorrect integer value: '' for column 'move_positions' at row 10")
#   result = self._query(query)
# /Users/shixinying/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:165: Warning: (1366, "Incorrect integer value: '' for column 'move_positions' at row 11")
#   result = self._query(query)
# /Users/shixinying/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:165: Warning: (1366, "Incorrect integer value: '' for column 'move_positions' at row 12")
# ...

# %%
#Check how many rows are in the table
# %sql select count(*) from ranking
# Out:
# 1 rows affected.
# [(196497,)]

# %% [markdown]
# ### Part 4: Scrape hashtags data from Twitter

# %% [markdown]
# #### 4.1 Authorizing an application to access Twitter account data

# %%
import tweepy 
import pandas as pd
import csv

consumer_key = 'gWnX6L9mVNmA7KGOnUz38Vj6L'
consumer_secret = 'NUj4HlFqqsKNRymkpNdHkGlz5XWywy8WTulpuCk4E9el0ejDhp'
access_token = '3299502536-ftNdzck0S2vTc0jigoouDXSx9WuYqkn6soXyqJy'
access_secret = 'XnYMNuNBHbcAYp3RFmhMj7v9ZP6KDDOl46mpKCLYji8V6'


auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
api = tweepy.API(auth)
if (not api):
    print ("Problem connecting to API")

# %%
statuses = api.home_timeline(count = 50)
print (statuses)
# Out:
# [Status(_api=<tweepy.api.API object at 0x10f57afd0>, _json={'created_at': 'Wed Feb 28 22:40:34 +0000 2018', 'id': 968979267093606401, 'id_str': '968979267093606401', 'text': 'RT @usta: See @ucf_mtennis &amp; @ucf_wtennis take on #USTATop25 teams @umichtennis in #CollegeMatchDay at the USTA #NationalCampus on Mar. 3 a…', 'truncated': False, 'entities': {'hashtags': [{'text': 'USTATop25', 'indices': [54, 64]}, {'text': 'CollegeMatchDay', 'indices': [87, 103]}, {'text': 'NationalCampus', 'indices': [116, 131]}], 'symbols': [], 'user_mentions': [{'screen_name': 'usta', 'name': 'USTA', 'id': 14836219, 'id_str': '14836219', 'indices': [3, 8]}, {'screen_name': 'UCF_MTennis', 'name': "UCF Men's Tennis", 'id': 1132041349, 'id_str': '1132041349', 'indices': [14, 26]}, {'screen_name': 'UCF_WTennis', 'name': "UCF Women's Tennis", 'id': 30278013, 'id_str': '30278013', 'indices': [33, 45]}, {'screen_name': 'umichtennis', 'name': 'Michigan Tennis', 'id': 27905245, 'id_str': '27905245', 'indices': [
# ...

# %% [markdown]
# #### 4.2 Extracting create time, text, user ids, user location, hashtags and key words from tweets

# %%
def array2csv(array, filename):
    csv_array = array
    csv_out = open(filename + ".csv", 'w')
    mywriter = csv.writer(csv_out)
    for row in csv_array:
        mywriter.writerow(row)
    csv_out.close()

# %%
#Getting Tweets
import json

search_words = ['Marin Cilic','Rafael Nadal','Roger Federer','Novak Djokovic','Andy Murray','David Ferrer','David Goffin','Hyeon Chung','Grigor Dimitrov','Alexander Zverev','Dominic Thiem','Kevin Anderson','Jack Sock','Sam Querrey','Stan Wawrinka','Lucas Pouille','Kei Nishikori']
search_tag =['#Tennis','#Laureus18','#ATPChanllenge','#ATP','#NextGenATP','#USOpen','#Wimbledon','ATPWorldTour','#AUOpen','#ChinaOpen']
q = 'station' 
n = 1050
from urllib.parse import unquote
search_results = api.search(q = q, count = n)

# %%
twitter_info = []
for word in search_words:
     for tweet in api.search(q = word, count = 2000):
            for hashtag in tweet.entities.get('hashtags'): 
                twitter_info.append([tweet.created_at, tweet.text, tweet.user.id,tweet.user.location, hashtag.get('text'),word])
                print(tweet.created_at,tweet.text, tweet.user.id,tweet.user.location, hashtag, word)


filename = "twitter_info"
array2csv(twitter_info, filename)
print("success")
# Out:
# 2018-02-28 23:04:24 RT @HoroscopeOfUSA: September 8, 2014- Marin Čilić of Croatia defeats @keinishikori of Japan in straight sets to win @usopen #FullMoon http… 319525951 United States {'text': 'FullMoon', 'indices': [125, 134]} Marin Cilic
# 2018-02-28 23:03:21 September 8, 2014- Marin Čilić of Croatia defeats @keinishikori of Japan in straight sets to win @usopen #FullMoon https://t.co/9aFrfRcDQZ 874102244 thehoroscopeoftheusa@gmail.com {'text': 'FullMoon', 'indices': [105, 114]} Marin Cilic
# 2018-02-28 15:37:41 RT @Bantibro: #TeamEXO
# "Ingvar Kamprad" "Marin Cilic" "Roger Federer" .
# In the films today when the daily  crimes, murders, robberies are… 852529896974897161 Sikar, Rajasthan {'text': 'TeamEXO', 'indices': [14, 22]} Marin Cilic
# 2018-02-28 15:37:31 RT @Eamesh2: @Pontifex #TeamEXO
# "Ingvar Kamprad" "Marin Cilic" "Roger Federer" .
# ...

# %% [markdown]
# #### 4.3 Create table 'tag' and import the data into it

# %%
# %sql CREATE TABLE IF NOT EXISTS tag (tag_id int PRIMARY KEY AUTO_INCREMENT,\
                                         create_at DATETIME,\
                                         tweet_text varchar(2000) CHARACTER SET utf8mb4,\
                                         user_id bigint,\
                                         user_location varchar(200) CHARACTER SET utf8mb4,\
                                         tag_text varchar(100),\
                                         key_word varchar(100)\
                                        )
# Out:
# 0 rows affected.
# []

# %%
# Import the data
# %sql LOAD DATA INFILE '/Users/shixinying/Desktop/ATPdataset/twitter_info.csv' \
INTO TABLE tag CHARACTER SET utf8mb4 \
FIELDS TERMINATED BY ',' \
ENCLOSED BY '"'\
(create_at, tweet_text, user_id, user_location, tag_text, key_word)
# Out:
# 852 rows affected.
# []

# %% [markdown]
# ### Part 5: Answer the questions

# %% [markdown]
# #### 5.1 What are the tags associated with a person, place, thing?

# %%
#Search the tags of player "Roger Federer"
# %sql SELECT tag.tag_text FROM tag \
WHERE tag.key_word LIKE 'Roger Federer%'
# Out:
# 55 rows affected.
# [('TENISxESPN',),
#  ('Laureus',),
#  ('TENISxESPN',),
#  ('Laureus',),
#  ('estimates',),
#  ('auspol',),
#  ('beBee',),
#  ('NewsOnTV3',),
#  ('3NewsGH',),
#  ('3Sports',),
#  ('TENISxESPN',),
#  ('Deportes',),
#  ('Tenis',),
#  ('TENISxESPN',),
#  ('estimates',),
#  ('auspol',),
#  ('TENISxESPN',),
#  ('Deportes',),
#  ('Notitarde',),
#  ('TENISxESPN',),
#  ('estimates',),
#  ('auspol',),
#  ('TENISxESPN',),
#  ('Nadal',),
#  ('Federer',),
#  ('TENISxESPN',),
#  ('estimates',),
#  ('auspol',),
#  ('Laureus18',),
#  ('estimates',),
#  ('auspol',),
#  ('TENISxESPN',),
#  ('Federer',),
#  ('Laureus18',),
#  ('RogerFederer',),
#  ('BenedictCumberbatch',),
#  ('estimates',),
#  ('auspol',),
#  ('estimates',),
#  ('auspol',),
#  ('TENISxESPN',),
#  ('website',),
#  ('Nadal',),
#  ('Federer',),
#  ('TENISxESPN',),
#  ('packs',),
#  ('TENISxESPN',),
#  ('TENISxESPN',),
#  ('Laureus18',),
#  ('Laureus2018',),
#  ('Laureus18',),
#  ('Laureus18',),
#  ('BolaSportLive',),
# ...

# %%
#Search the tags of player "Rafael Nadal"
# %sql SELECT tag.tag_text FROM tag \
WHERE tag.key_word LIKE 'Rafael Nadal%'
# Out:
# 93 rows affected.
# [('Deportes',),
#  ('México',),
#  ('Deportes',),
#  ('México',),
#  ('beBee',),
#  ('ÚLTIMAHORA',),
#  ('AFP',),
#  ('FSRadioMX',),
#  ('Nadal',),
#  ('Federer',),
#  ('Nadal',),
#  ('Federer',),
#  ('Nadal',),
#  ('Federer',),
#  ('Laureus18',),
#  ('Nadal',),
#  ('Federer',),
#  ('Nadal',),
#  ('Federer',),
#  ('Oaxaca',),
#  ('Nadal',),
#  ('IndianWells',),
#  ('Tennis',),
#  ('ATP',),
#  ('ATPTour',),
#  ('MexicanOpen',),
#  ('AMT2018',),
#  ('Laureus18',),
#  ('Nadal',),
#  ('Federer',),
#  ('Nadal',),
#  ('Federer',),
#  ('AMT2018',),
#  ('Nadal',),
#  ('Federer',),
#  ('Deportes',),
#  ('AbiertoMexicanodeTenis',),
#  ('Nadal',),
#  ('Federer',),
#  ('Nadal',),
#  ('Federer',),
#  ('Nadal',),
#  ('Nadal',),
#  ('Federer',),
#  ('Nadal',),
#  ('Federer',),
#  ('Deportes',),
#  ('México',),
#  ('Nadal',),
#  ('Federer',),
#  ('Nadal',),
#  ('Nadal',),
#  ('Federer',),
#  ('Nadal',),
#  ('Federer',),
#  ('RAFAELNADAL',),
#  ('Nadal',),
#  ('Laureus18',),
# ...

# %% [markdown]
# #### 5.2 What social media users are like other social media users in your domain?

# %%
# Firstly, search all the users from Australia
# %sql SELECT tag.user_id FROM tag \
WHERE tag.user_location LIKE "%Australia%"
# Out:
# 11 rows affected.
# [(101636476,),
#  (41325484,),
#  (41325484,),
#  (101636476,),
#  (169332508,),
#  (169332508,),
#  (85795383,),
#  (85795383,),
#  (182839067,),
#  (182839067,),
#  (182839067,)]

# %% [markdown]
# ##### Cause the user_id is not the Primary key in table 'tag', so, we just need to filter the same id after affecting the data.

# %%
user1 = api.get_user(85795383)
print(user1.name, user1.screen_name, str(user1.statuses_count), str(user1.friends_count), str(user1.followers_count))
# Out:
# RonnyB MsRonnyB 159272 6927 8429

# %%
from datetime import datetime, date, time, timedelta
tweets = user1.statuses_count
account_created_date = user1.created_at
delta = datetime.utcnow() - account_created_date
account_age_days = delta.days
print("Account age (in days): " + str(account_age_days))
if account_age_days > 0:
    print("Average tweets per day: " + "%.2f"%(float(tweets)/float(account_age_days)))
# Out:
# Account age (in days): 3045
# Average tweets per day: 52.31

# %%
from tweepy import Cursor
hashtags = []
mentions = []
tweet_count = 0
end_date = datetime.utcnow() - timedelta(days=100)
for status in Cursor(api.user_timeline, id=182839067).items():
      tweet_count += 1
      if hasattr(status, "entities"):
        entities = status.entities
        if "hashtags" in entities:
          for ent in entities["hashtags"]:
            if ent is not None:
              if "text" in ent:
                hashtag = ent["text"]
                if hashtag is not None:
                  hashtags.append(hashtag)
        if "user_mentions" in entities:
          for ent in entities["user_mentions"]:
            if ent is not None:
              if "screen_name" in ent:
                name = ent["screen_name"]
                if name is not None:
                  mentions.append(name)
      if status.created_at < end_date:
        break

# %%
hashtags
# Out:
# ['RolandGarros',
#  'Wawrinka',
#  'Djokovic',
#  'USOPEN',
#  'tennis',
#  'TENNIS',
#  'Federer',
#  'tennis',
#  'tennis',
#  'atp',
#  'SicEm',
#  'SicEm',
#  'Dimitrov',
#  'AusOpen',
#  'CHUNG',
#  'ATP',
#  'AusOpen',
#  'AusOpen',
#  'AusOpen',
#  'Federer',
#  'AusOpen',
#  'Federer',
#  'Cilic',
#  'Federer',
#  'Cilic',
#  'Federer',
#  'AusOpen',
#  'Federer',
#  'FEDERER',
#  'CILIC',
#  'AusOpen',
#  'Wozniacki',
#  'Halep',
#  'AusOpen',
#  'AusOpen',
#  'Halep',
#  'Wozniacki',
#  'Halep',
#  'Wozniacki',
#  'yourfriendcanreadittomorrowalongwitheveryotherplayer',
#  'AusOpen',
#  'AusOpen',
#  'Wozniacki',
#  'Wozniacki',
#  'Halep',
#  'AusOpen',
#  'AusOpen',
#  'Federer',
#  'AusOpen',
#  'Federer',
#  'Federer',
#  'AusOpen',
#  'Federer',
#  'Federer',
#  'Federer',
#  'Chung',
#  'Federer',
#  'Chung',
#  'AusOpen',
#  'AusOpen',
#  'AusOpen',
#  'AusOpen',
#  'AusOpen',
#  'AusOpen',
#  'Halep',
#  'Pliskova',
#  'Federer',
#  'Berdych',
#  'AusOpen',
# ...

# %%
from collections import Counter
for user1, count in Counter(mentions).most_common(10):
      print(user1 + "\t" + str(count))
# Out:
# AustralianOpen	9
# _markpetchey	5
# claire88cairns	5
# NickMcCarvel	5
# dkrolfe	4
# RafaelNadal	3
# CodyFitz96	3
# ausassault	2
# Tennis_Parents	2
# Reloadednow	2

# %%
for user1, count in Counter(hashtags).most_common(10):
      print(user1 + "\t" + str(count))
# Out:
# AusOpen	49
# Federer	15
# tennis	9
# Dimitrov	8
# Kyrgios	6
# Wozniacki	5
# Halep	5
# TENNIS	4
# atp	3
# Cilic	3

# %%
user2 = api.get_user(41325484)
print(user2.name, user2.screen_name, str(user2.statuses_count), str(user2.friends_count), str(user2.followers_count))
# Out:
# Amber AmberRajen 49950 885 1595

# %%
from datetime import datetime, date, time, timedelta
tweets = user2.statuses_count
account_created_date = user2.created_at
delta = datetime.utcnow() - account_created_date
account_age_days = delta.days
print("Account age (in days): " + str(account_age_days))
if account_age_days > 0:
    print("Average tweets per day: " + "%.2f"%(float(tweets)/float(account_age_days)))
# Out:
# Account age (in days): 3206
# Average tweets per day: 15.58

# %%
from tweepy import Cursor
hashtags = []
mentions = []
tweet_count = 0
end_date = datetime.utcnow() - timedelta(days=100)
for status in Cursor(api.user_timeline, id=41325484).items():
      tweet_count += 1
      if hasattr(status, "entities"):
        entities = status.entities
        if "hashtags" in entities:
          for ent in entities["hashtags"]:
            if ent is not None:
              if "text" in ent:
                hashtag = ent["text"]
                if hashtag is not None:
                  hashtags.append(hashtag)
        if "user_mentions" in entities:
          for ent in entities["user_mentions"]:
            if ent is not None:
              if "screen_name" in ent:
                name = ent["screen_name"]
                if name is not None:
                  mentions.append(name)
      if status.created_at < end_date:
        break

# %%
hashtags
# Out:
# ['Laureus18',
#  'Nadal',
#  'Federer',
#  'resigning',
#  'Laureus2018',
#  'RogerFederer',
#  'AusOpen',
#  'rogerfederer',
#  'Laureus18',
#  'LaureusAwards',
#  'Laureus18',
#  'Laureus18',
#  'laureus18',
#  'Laureus18',
#  'Laureus18',
#  'Laureus18',
#  'Laureus18',
#  'Laureus18',
#  'Laureus18',
#  'RogerFederer',
#  'Laureus18',
#  'nr1',
#  'SupportTheSwiss',
#  'Laureus18',
#  'Laureus18',
#  'Laureus18',
#  'Laureus18',
#  'Laureus18',
#  'Laureus18',
#  'AusOpen',
#  'Laureus18',
#  'DBO2018',
#  'USOpen',
#  'Federer',
#  'tennis',
#  'DDFTennis',
#  'DDFTennis',
#  'AusOpen',
#  'FridayFeeling',
#  'NEVERAGAIN',
#  'MarchForOurLives',
#  'TBT',
#  'OnThisDay',
#  'Wimbledon',
#  'OnThisDay',
#  'OnlyNetJets',
#  'Federer',
#  'lillustre',
#  'SmashTalk',
#  'WhatsAtStake',
#  'Pyeongchang2018',
#  'AusOpen',
#  'TheFostersOnEllen',
#  'ATPRankings',
#  'Federer',
#  'Parkland',
#  'USOpen',
#  'USOpen',
#  'USOpen50',
#  'blackpanther',
#  'Wimbledon',
# ...

# %%
from collections import Counter
for user2, count in Counter(mentions).most_common(10):
      print(user2 + "\t" + str(count))
# Out:
# rogerfederer	560
# AustralianOpen	312
# 7tennis	80
# ATPWorldTour	59
# abnamrowtt	40
# Ubitennis	38
# TennisTV	37
# smh	33
# LaureusSport	31
# nytimes	28

# %%
for user2, count in Counter(hashtags).most_common(10):
      print(user2 + "\t" + str(count))
# Out:
# AusOpen	295
# Federer	44
# RF20	29
# abnamrowtt	27
# Laureus18	18
# 7Tennis	18
# ausopen	14
# HopmanCup	14
# USOpen	9
# Wimbledon	7

# %% [markdown]
# ##### We search people who come from the same country (Australia) and also posted some tweets about tennis in the past, then we compare tags in their tweets in past 100 days, we find the most common tags for two of them are both about Australian Open and Roger Federer, so they are similar user.

# %% [markdown]
# #### 5.3 What people, places or things are popular in your domain?

# %%
# %sql SELECT tag.tag_text,count(*) AS count FROM tag GROUP BY tag.tag_text HAVING count>1 ORDER BY COUNT DESC LIMIT 10 OFFSET 1
# Out:
# 10 rows affected.
# [('AMTxESPN', 46),
#  ('Nadal', 32),
#  ('Deportes', 32),
#  ('AMT2018', 29),
#  ('Federer', 29),
#  ('Tennis', 27),
#  ('Shapovalov', 22),
#  ('Zverev', 22),
#  ('Nishikori', 21),
#  ('TENISxESPN', 19)]

# %% [markdown]
# #### 5.4 What people, places or things are trending in your domain? (A trend is popularity over time.)

# %% [markdown]
# ##### Because we could just fetch data in a short time(between a day). So we could just try to retrieve the trending over a day. And we use the query to count quentity of different tags in a day.

# %%
# %sql SELECT tag.tag_text,count(*) AS count FROM tag WHERE tag.create_at BETWEEN '2018-02-28 00:00:00' and  '2018-02-28 23:59:59' \
GROUP BY tag.tag_text HAVING count>1  \
ORDER BY COUNT DESC
# Out:
# 87 rows affected.
# [('AMTxESPN', 43),
#  ('acapulco', 42),
#  ('Deportes', 32),
#  ('Nadal', 32),
#  ('Federer', 29),
#  ('AMT2018', 28),
#  ('Tennis', 26),
#  ('Shapovalov', 22),
#  ('Nishikori', 21),
#  ('Zverev', 20),
#  ('TENISxESPN', 19),
#  ('ATP', 19),
#  ('Dubai', 17),
#  ('Thiem', 12),
#  ('ATP500Acapulco', 11),
#  ('MexicanOpen', 10),
#  ('Pouille', 9),
#  ('DelPotro', 9),
#  ('Tenis', 9),
#  ('???', 8),
#  ('AMT18', 8),
#  ('Laureus18', 8),
#  ('KitKabin', 8),
#  ('Dimitrov', 8),
#  ('????_???????', 8),
#  ('WIN', 7),
#  ('MomentoDelpo', 7),
#  ('1R', 7),
#  ('NextGenATP', 7),
#  ('SanCristóbal', 7),
#  ('ATPAcapulco', 7),
#  ('estimates', 7),
#  ('Retweet', 7),
#  ('Ferrer', 7),
#  ('auspol', 7),
#  ('COMPETITION', 7),
#  ('Norrie', 7),
#  ('Laureus', 6),
#  ('ddftennis', 6),
#  ('AMTXXV', 6),
#  ('Entérate', 6),
#  ('Gojowczyk', 6),
#  ('2R', 6),
#  ('Wawrinka', 4),
#  ('Khachanov', 4),
#  ('sport', 4),
#  ('AbiertoTelcel', 4),
#  ('Sock', 4),
#  ('México', 4),
# ...
